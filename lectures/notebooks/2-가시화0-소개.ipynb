# %% [markdown]
# ## 시각화의 중요성
#
# - 데이터 셋이 가진 기초 통계량만 가지고 데이터 셋을 판단하는 것은 무리가 있다
# - 데이터 전처리 과정 중에 시각화를 통해서 실제 데이터 셋의 모양을 살펴보는 것이 좋다
#
#
# 다양한 그래프
#
# 1. 일변량(1개)
#     - 연속형 : 히스토그램, 상자수염(boxplot), 바이올린(violin), 커널 밀도 (Kernel density curve)
#     - 범주형 : 막대 그래프(bar chart), 파이 그래프(pie chart)
#
# 2. 다변량( 2개 이상)
#     - 연속형 : 산점도(scatter), 선 그래프, 시계열 그래프
#     - 범주형 : 모자이크 그래프(mosaic), Tree map

# %% [markdown]
# ## 시각화 도구
#
# ### matplotlib
#
#
# 데이터를 시각화하는 패키지. 기본적으로 Mathlab 그래프 함수와 유사하다. 그래서 matplotlib는 MATLAB 같이 명령 스타일 함수 (command style functions)들 모음이라고 한다. 여러 하위 모듈이 있다.
#
#  - matplotlib.pyplot

# %%
# ! conda install -y matplotlib

# %%
# pip install matplotlib

# %% [markdown]
# ### 쥬피터노트북
#
# 쥬피터노트북은 Magic`%matplotlib inline` 을 사용하면 cell에서 그래프를 볼 수 있다. 즉,[ jupyter에게 어떤 GUI로 출력](http://ipython.org/ipython-doc/2/interactive/reference.html#gui-event-loop-support) 할 지 지정해 준다:
#  - https://matplotlib.org/stable/users/interactive.html
#
# ```
# %matplotlib notebook
# %matplotlib inline
# ```

# %% [markdown]
# # Matplotlib
#
# ![image.png](attachment:3975b960-b2e7-4dc9-bd5a-14e6be8e2436.png)

# %% [markdown]
# Matplot lib 세부 튜토리얼
#
# > - [Matplotlib Tutorial - 파이썬으로 데이터 시각화하기, Wikidoc](https://wikidocs.net/book/5011)
# > - https://wikidocs.net/92089
# > - 효과적으로 matplotlib사용하기 [링크](http://pbpython.com/effective-matplotlib.html)
# > - Matplotlib를 사용한 시각화 예제들을 보고 싶다면 Matplotlib [갤러리](http://matplotlib.org/gallery.html)를 방문하세요.
# > - 데이터 사이언스 스쿨의 Matplotlib [소개](https://datascienceschool.net/view-notebook/d0b1637803754bb083b5722c9f2209d0/)

# %% [markdown]
# 단순 선 그래프 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#data 작성
np.random.seed(1) #난수를 고정
x = np.arange(10)
y = np.random.rand(10)

# 그래프 표시
plt.plot(x,y) #꺾은선 그래프를 등록
plt.show() # 그래프 그리기

# %% [markdown]
# # Plotly
#
# 2차원, 3차원 웹 기반 인터랙티브 차트
#
# ![image.png](attachment:990ac81a-d2b6-4b52-98f2-2fc492efa3a7.png)

# %% [markdown]
# # Folium
#
# Folium은 'Python data, leaflet.js maps'의 강점을 내세운 라이브러리입니다. 데이터는 파이썬으로 조작하고, 그 결과는 leaflet.js를 통해 지도 시각화할 수 있습니다.
#
# - Folium 공식 홈페이지 | https://python-visualization.github.io/folium/
