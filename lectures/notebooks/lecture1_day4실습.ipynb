# %% [markdown]
# # 실습 : 10:25 분 ~ 10:35 분

# %% [markdown]
# ![image.png](attachment:bc9f80d6-4a2a-456d-9b7e-3a684e57244e.png)

# %%
while True:
    num1 = int(input('첫번째 정수를 입력하시오(0은 종료)'))
    num2 = int(input('두번째 정수를 입력하시오(0은종료)'))
    num3 = int(input('세번째 정수를 입력하시오(0은종료)'))

    max = num1 if num1 > num2 else num2      # 앞의 두수 중에서 큰값을 max에 넣기
    max = num3 if num3 > max else max        # max와 마지막 수에서 큰값을 max에 넣기
    
    min = num1 if num1 < num2 else num2      # 앞의 두수 중에서 작은값을 max에 넣기
    min = num3 if num3 < min else min        # min과 마지막 수에서 작은값을 min에 넣기

    print('최대값은 {0}입니다.'.format(max))
    print('최소값은 {0}입니다.'.format(min))
# Out:
# 첫번째 정수를 입력하시오(0은 종료) 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 while True:
#       2     num1 = int(input('첫번째 정수를 입력하시오(0은 종료)'))
# ----> 3     num2 = int(input('두번째 정수를 입력하시오(0은종료)'))
#       4     num3 = int(input('세번째 정수를 입력하시오(0은종료)'))
#       5     if num1 == 0 or num2 == 0 or num3 == 0:
#
# File ~\anaconda3\envs\Python_basic\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# ...

# %%
while True:
    num1 = input('첫번째 정수를 입력하시오(0은 종료)')
    if not num1:
        continue
    else:
        num1 = int(num1)
    num2 = int(input('두번째 정수를 입력하시오(0은종료)'))
    num3 = int(input('세번째 정수를 입력하시오(0은종료)'))
    
    max = num1 if num1 > num2 else num2      # 앞의 두수 중에서 큰값을 max에 넣기
    max = num3 if num3 > max else max        # max와 마지막 수에서 큰값을 max에 넣기
    
    min = num1 if num1 < num2 else num2      # 앞의 두수 중에서 작은값을 max에 넣기
    min = num3 if num3 < min else min        # min과 마지막 수에서 작은값을 min에 넣기

    print('최대값은 {0}입니다.'.format(max))
    print('최소값은 {0}입니다.'.format(min))
# Out:
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료)
# 첫번째 정수를 입력하시오(0은 종료) 0
# 두번째 정수를 입력하시오(0은종료) 0
# 세번째 정수를 입력하시오(0은종료) 0
# 최대값은 0입니다.
# 최소값은 0입니다.
# 첫번째 정수를 입력하시오(0은 종료) 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       5 else:
#       6     num1 = int(num1)
# ----> 8 num2 = int(input('두번째 정수를 입력하시오(0은종료)'))
#      10 num3 = int(input('세번째 정수를 입력하시오(0은종료)'))
#      12 max = num1 if num1 > num2 else num2      # 앞의 두수 중에서 큰값을 max에 넣기
#
# File ~\anaconda3\envs\Python_basic\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
# ...

# %% [markdown]
# # 실습 : 13:00 ~ 13:08분 까지
#
# https://github.com/qkboo/Lecture_KDT2/blob/master/lectures/day4_%EC%8B%A4%EC%8A%B5_2.png
#
# ![image.png](attachment:6f7000e4-b234-42fc-b64f-5e282886b68e.png)

# %% [markdown]
# 시작과 끝 범위 숫자를 입력받아 5의 배수가 아닌수의 합계를 계산한다

# %%
n1 = int(input('시작 수를 입력하세요 : '))
n2 = int(input('끝 수를 입력하세요 : '))

sum = 0
for i in range(n1, n2+1) :
    if i % 5 != 0 :
        sum += i

print('-' * 50)
print('%d에서 %d까지 5의 배수가 아닌 수의 합계 : %d' % (n1, n2, sum))

# %% [markdown]
# 시작과 끝 범위 숫자를 입력받아 5의 배수의 합계를 계산한다. 단, 합이 200 넘으면 종료한다.

# %%
n1 = int(input('시작 수를 입력하세요 : '))
n2 = int(input('끝 수를 입력하세요 : '))

sum = 0
for i in range(n1, n2+1) :
    if i % 5 == o :
        sum += i
    if sum > 200:
        break
print('-' * 50)
print('%d에서 %d까지 5의 배수 합이 200을 넘는 위치 합계 : %d' % (n1, n2, sum))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 n1 = int(input('시작 수를 입력하세요 : '))
#       2 n2 = int(input('끝 수를 입력하세요 : '))
#       4 sum = 0
#
# File ~\anaconda3\envs\Python_basic\lib\site-packages\ipykernel\kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# File ~\anaconda3\envs\Python_basic\lib\site-packages\ipykernel\kernelbase.py:1217, in Kernel._input_request(self, prompt, ident, parent, password)
#    1214             break
#    1215 except KeyboardInterrupt:
# ...

# %% [markdown]
# # 실습 : 15:15 ~ 15:35분 까지

# %% [markdown]
# # "실습" 1에서 20사이 숫자 중에 짝수는 `*`, 홀수는 `+` 를 출력하세요
#
# ```
# +
# **
# +++
# ****
# +++++
# ******
# +++++++
# ********
# +++++++++
# **********
# +++++++++++
# ```

# %%
# 반복!!!
for x in range(1, 21):
    if x % 2 == 0: #짝수
        print(x * '*')
    else:
        print(x * '+')
# Out:
# +
# **
# +++
# ****
# +++++
# ******
# +++++++
# ********
# +++++++++
# **********
# +++++++++++
# ************
# +++++++++++++
# **************
# +++++++++++++++
# ****************
# +++++++++++++++++
# ******************
# +++++++++++++++++++
# ********************

# %% [markdown]
# # "실습" for 문으로 아래 형태로 출력하게 작성.
#
# ```
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# ```

# %%
for i in range(5) :
    for j in range(10) :
        print('* ', end=' ')
    print()
# Out:
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *

# %% [markdown]
# # "실습" while 문으로 아래 형태로 출력하게 작성.
#
# ```
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# ```

# %%
i = 0
while i < 5 :
    j = 0
    while j < 10 :
        print('* ', end=' ')
        
        j += 1
    print()
    
    i += 1
# Out:
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *
# *  *  *  *  *  *  *  *  *  *

# %% [markdown]
# # "실습" 튜플/리스트을 이용하고 아래 같이 1-9단 구구단 표를 출력하세요.
#
# ```
# 구구단표
# ------------------------------
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# ...
# ```

# %%
nums = (2, 3, 4, 5, 6, 7, 8, 9)    # Interable

print('구구단표')
print('-' * 30)

for i in nums :
    for j in range(1, 10) :
        print('%d x %d = %d' % (i, j , i*j))
    print('-' * 30)
