# %% [markdown]
# # 유튜브 랭킹 데이터 수집하기
#
# > 2022/09-01:
# > 직장인을 위한 데이터 분석 실무/3장

# %% [markdown]
# ## - 필요 모듈 설치
#
# 최신 Selenium is upgraded to v4.x
#
# ```
# pip3 install -U selenium
# pip3 install webdriver-manager
# ```
#
#
# Selenium 3 까지는 selenium 만 설치해도 충분.
#
# ```
# pip install --user selenium
# ```

# %%
! pip install -U selenium

# %%
! pip install webdriver-manager

# %% [markdown]
# # 1. 유튜브 랭킹 데이터 수집하기
#
# ![image.png](attachment:0c32c0ad-8243-4b75-95dc-4941270ed30f.png)

# %% [markdown]
# ### 유튜브 랭킹 접속

# %%
# 라이브러리 추가하기
from selenium import webdriver
webdriver.__version__
# Out:
# '4.5.0'

# %%
from bs4 import BeautifulSoup 
import time
import pandas as pd

# %%
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# create a new chrome session
options = Options()
options.add_argument('headless') #--headless
options.add_argument('no-sandbox') #--no-sandbox

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
url = "https://youtube-rank.com/board/bbs/board.php?bo_table=youtube" 
driver.get(url)

driver.save_screenshot("youtube-rank.com-01.png")
# Out:
# [WDM] - Downloading: 100%|█████████████████████████████████████████████████████████| 7.26M/7.26M [00:00<00:00, 9.90MB/s]
# True

# %%
# 페이지 정보 가져오기
html = driver.page_source

# %%
html[:200]
# Out:
# '<html lang="ko"><head>\n    <meta charset="utf-8">\n    <meta http-equiv="imagetoolbar" content="no">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>유튜브 랭킹 1 페이지</title>\n    <link rel='

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
# BeautifulSoup으로 tr 태그 추출하기
channel_list = soup.select('tr') 
print(len(channel_list), '\n')
print(channel_list[0])
# Out:
# 102
#
# <tr>
# <th class="rank"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=rank&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">순위 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="td_img">이미지</th>
# <th class="subject">제목</th>
# <th class="subscriber_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=subscriber_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">구독자순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="view_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=view_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">View순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="video_cnt"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=video_cnt&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">Video순 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# <th class="hit"><a href="/board/bbs/board.php?bo_table=youtube&amp;sop=and&amp;sst=wr_hit&amp;sod=desc&amp;sfl=&amp;stx=&amp;sca=&amp;page=1">조회수 <i aria-hidden="true" class="fa fa-sort"></i></a></th>
# </tr>

# %%
# tr 태그 확인하기
channel_list = soup.select('form > table > tbody > tr')
print(len(channel_list))
# Out:
# 100

# %%
# 채널 태그 출력 및 태그구조 확인하기
channel = channel_list[0]
print(channel)
# Out:
# <tr class="aos-init aos-animate" data-aos="fade-up" data-aos-duration="800">
# <td class="rank">
#                         1                    </td>
# <td class="td_img">
# <div class="info_img"><a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203"><img class="lazyload" data-src="https://yt3.ggpht.com/hZDUwjoeQqigphL4A1tkg9c6hVp5yXmbboBR7PYFUSFj5PIJSA483NB5v7b0XVoTN9GCku3tqQ=s88-c-k-c0x00ffffff-no-nd-rj" height="88" src="https://yt3.ggpht.com/hZDUwjoeQqigphL4A1tkg9c6hVp5yXmbboBR7PYFUSFj5PIJSA483NB5v7b0XVoTN9GCku3tqQ=s88-c-k-c0x00ffffff-no-nd-rj" width="88"/></a></div>
# <p class="info_rank">1</p>
# </td>
# <td class="subject">
# <h1>
# <p <a="" class="category" href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;sca=%EC%9D%8C%EC%95%85%2F%EB%8C%84%EC%8A%A4%2F%EA%B0%80%EC%88%98">[음악/댄스/가수]
#
#                                 </p>
# <a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203">
#
# 								BLACKPINK							</a>
# <span>
# <i class="fa fa-comment"></i>
# 								1							</span>
# <i aria-hidden="true" class="fa fa-heart"></i> </h1>
# <h2><span><a href="https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&amp;wr_id=3203">"YG Entertainment" YG 와이지 K-pop BLACKPINK 블랙핑크 블핑 제니 로제 리사 지수 Lisa Jisoo Jennie ...</a></span></h2>
# <h3>
# <i class="fa fa-user"></i>
#                             8310만<i class="fa fa-play"></i>280억1103만                            <i class="fa fa-video-camera"></i>
#                             451                            <i class="fa fa-eye"></i>
#                             23,819                        </h3>
# </td>
# <td class="subscriber_cnt">8310만</td>
# <td class="view_cnt">280억1103만</td>
# <td class="video_cnt">451개</td>
# <td class="hit">
# <strong>23,819</strong>
# <span>HIT</span>
# </td>
# </tr>

# %%
# 카테고리 정보 추출하기
category = channel.select('p.category')[0].text.strip()
print(category)
# Out:
# [음악/댄스/가수]

# %%
# 채널명 찾아오기
title = channel.select('h1 > a')[0].text.strip()
print(title)
# Out:
# BLACKPINK

# %%
# 구독자 수, View 수, 동영상 수 추출하기
subscriber = channel.select('.subscriber_cnt')[0].text
view = channel.select('.view_cnt')[0].text
video = channel.select('.video_cnt')[0].text

print(subscriber)
print(view)
print(video)
# Out:
# 8310만
# 280억1103만
# 451개

# %%
# 반복문으로 채널 정보 추출하기
channel_list = soup.select('tbody > tr') 
for channel in channel_list:
    tag_a =  channel.select('h1 > a')
    if tag_a:
        title = tag_a[0].text.strip()
        category = channel.select('p.category')[0].text.strip()
        subscriber = channel.select('.subscriber_cnt')[0].text
        view = channel.select('.view_cnt')[0].text
        video = channel.select('.video_cnt')[0].text 
        print(title, category, subscriber, view, video)
# Out:
# BLACKPINK [음악/댄스/가수] 8310만 280억1103만 451개
# BANGTANTV [음악/댄스/가수] 7210만 185억8512만 1,858개
# HYBE LABELS [음악/댄스/가수] 6890만 252억7790만 1,036개
# SMTOWN [음악/댄스/가수] 3110만 259억0878만 4,001개
# Boram Tube Vlog [보람튜브 브이로그] [키즈/어린이] 2650만 110억5288만 223개
# JYP Entertainment [음악/댄스/가수] 2600만 180억8425만 1,587개
# 1MILLION Dance Studio [음악/댄스/가수] 2570만 75억6662만 4,688개
# 1theK (원더케이) [음악/댄스/가수] 2430만 230억6974만 17,519개
# Mnet K-POP [음악/댄스/가수] 1990만 136억4278만 29,627개
# KBS WORLD TV [TV/방송] 1840만 142억8856만 60,142개
# officialpsy [음악/댄스/가수] 1770만 101억3451만 121개
# JFlaMusic [음악/댄스/가수] 1760만 37억1766만 301개
# Jane ASMR 제인 [음식/요리/레시피] 1710만 67억8446만 1,659개
# TWICE [음악/댄스/가수] 1510만 42억1527만 953개
# BIGBANG [음악/댄스/가수] 1490만 75억0693만 776개
# Boram Tube ToysReview [보람튜브 토이리뷰] [키즈/어린이] 1440만 49억4521만 584개
# Hongyu ASMR 홍유 [음식/요리/레시피] 1430만 45억8582만 563개
# BIBO와 장난감 [키즈/어린이] 1270만 30억1646만 166개
# Kendrick Lamar [미분류] 1150만 51억0070만 21개
# Stray Kids [음악/댄스/가수] 1110만 24억0226만 678개
# 핑크퐁 (인기 동요・동화) [키즈/어린이] 1110만 68억2460만 2,850개
# Toymong tv 토이몽TV [키즈/어린이] 1070만 43억9934만 2,178개
# DuDuPopTOY [키즈/어린이] 1070만 49억4733만 2,334개
# [햄지]Hamzy [음식/요리/레시피] 1060만 34억8085만 500개
# Stone Music Entertainment [음악/댄스/가수] 1050만 92억2267만 9,451개
# 서은일상이야기 [키즈/어린이] 1040만 25억4803만 692개
# MBCkpop [TV/방송] 1000만 84억6248만 44,193개
# TOMORROW X TOGETHER OFFICIAL [음악/댄스/가수] 993만 10억0531만 1,251개
# Larva TUBA [키즈/어린이] 986만 44억0218만 2,066개
# 서은이야기[SeoeunStory] [키즈/어린이] 943만 32억9550만 1,174개
# 쏘영 Ssoyoung [음식/요리/레시피] 904만 12억1871만 681개
# EXO [음악/댄스/가수] 898만 6억9691만 316개
# Mnet TV [음악/댄스/가수] 896만 111억7004만 21,237개
# MBCentertainment [뉴스/정치/사회] 889만 164억4365만 94,353개
# Boram Tube [宝蓝和朋友们] [키즈/어린이] 888만 23억7941만 463개
# iKON [음악/댄스/가수] 876만 24억0785만 577개
# M2 [TV/방송] 874만 73억1260만 17,526개
# SEVENTEEN [음악/댄스/가수] 867만 33억8935만 1,295개
# Serie A [해외] 853만 31억5066만 24,103개
# 문복희 Eat with Boki [음식/요리/레시피] 846만 22억3159만 640개
# 이지금 [IU Official] [음악/댄스/가수] 822만 18억1405만 158개
# HUBA후바 [미분류] 803만 62억7325만 385개
# ITZY [음악/댄스/가수] 786만 18억5020만 829개
# MariAndKids [키즈/어린이] 760만 23억7008만 812개
# JTBC Entertainment [뉴스/정치/사회] 752만 113억0078만 74,977개
# tzuyang쯔양 [음식/요리/레시피] 739만 15억8090만 453개
# KBS Kpop [TV/방송] 735만 63억2080만 35,738개
# SonicToy소닉토이 [키즈/어린이] 731만 31억1837만 168개
# 야미보이 Yummyboy [음식/요리/레시피] 721만 28억9162만 1,008개
# GQ [미분류] 720만 28억9626만 1,981개
# 스브스케이팝 X INKIGAYO [TV/방송] 708만 54억1027만 31,518개
# Sungha Jung [음악/댄스/가수] 701만 19억5732만 1,358개
# ENHYPEN [미분류] 695만 10억1310만 683개
# MAMAMOO [음악/댄스/가수] 688만 22억1958만 784개
# YG ENTERTAINMENT [음악/댄스/가수] 687만 17억4500만 399개
# ALL THE K-POP [음악/댄스/가수] 677만 43억9798만 25,084개
# YouTube Originals [회사/오피셜] 671만 6억5520만 473개
# SBS Entertainment [TV/방송] 663만 83억3281만 223,997개
# 미니특공대TV [키즈/어린이] 662만 37억3226만 1,372개
# TREASURE (트레저) [음악/댄스/가수] 657만 17억4312만 610개
# [장난감티비]TOYTV [키즈/어린이] 650만 31억1357만 1,626개
# tvN drama [TV/방송] 645만 71억7110만 46,582개
# SBS Drama [TV/방송] 640만 69억3611만 344,118개
# GOT7 [음악/댄스/가수] 629만 8억7026만 579개
# Samsung [회사/오피셜] 627만 14억9464만 1,670개
# PONY Syndrome [패션/미용] 594만 3억6252만 232개
# With Kids Playground [위드키즈 놀이터] [키즈/어린이] 572만 21억4832만 437개
# PinkyPopTOY [키즈/어린이] 570만 9억6928만 1,521개
# starshipTV [음악/댄스/가수] 566만 36억2786만 2,088개
# 백종원 PAIK JONG WON [음식/요리/레시피] 562만 7억7218만 472개
# 스위트티비 SweetTV [키즈/어린이] 561만 28억2498만 437개
# GH'S [미분류] 560만 29억0524만 233개
# NCT [음악/댄스/가수] 557만 7억3147만 450개
# 2NE1 [음악/댄스/가수] 555만 21억6960만 321개
# 영국남자 Korean Englishman [BJ/인물/연예인] 545만 18억4867만 496개
# 5 분 Tricks [음식/요리/레시피] 540만 20억7386만 4,093개
# TOY GUMA [키즈/어린이] 538만 17억6908만 374개
# NCT DREAM [음악/댄스/가수] 536만 8억9664만 437개
# MayTree [미분류] 529만 10억7655만 186개
# 베이비버스 -인기 동요・동화 [키즈/어린이] 526만 36억9753만 1,518개
# 콩순이 · 시크릿쥬쥬 [Kongsuni · Secret Jouju] [키즈/어린이] 525만 48억8229만 1,384개
# 푸메Fume [음식/요리/레시피] 523만 11억3585만 614개
# Red Velvet [음악/댄스/가수] 522만 11억3723만 243개
# [Awesome Haeun]어썸하은 [BJ/인물/연예인] 521만 8억6159만 521개
# 미니팡TV [키즈/어린이] 518만 34억4933만 860개
# SBS NOW / SBS 공식 채널 [뉴스/정치/사회] 516만 54억6104만 22,779개
# Rosesarerosie [음악/댄스/가수] 515만 5188만 9개
# 채널 십오야 [TV/방송] 498만 12억4393만 703개
# KBS Entertain [TV/방송] 497만 86억0815만 112,100개
# NCT 127 [음악/댄스/가수] 496만 7억9226만 472개
# BT21 [음악/댄스/가수] 494만 4억4668만 279개
# ToyMart TV [키즈/어린이] 486만 20억8491만 659개
# MBCdrama [TV/방송] 485만 55억9386만 58,533개
# 떵개떵 [음식/요리/레시피] 484만 28억9108만 4,769개
# ASTRO 아스트로 [음악/댄스/가수] 482만 5억4256만 584개
# SBS TV동물농장x애니멀봐 [애완/반려동물] 473만 44억7667만 3,864개
# 뽀로로(Pororo) [키즈/어린이] 466만 66억0100만 4,038개
# Cooking tree 쿠킹트리 [음식/요리/레시피] 464만 4억6240만 1,379개
# JTBC Drama [TV/방송] 463만 49억5228만 26,541개
# 까니짱 [ G-NI : 蟹ちゃん] [음식/요리/레시피] 462만 13억2656만 699개

# %% [markdown]
# ### 페이지별 URL 만들기

# %%
# 페이지별 URL 만들기
page = 1



print(url)
# Out:
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1

# %% [markdown]
# #### 실습: 10페이지까지 크롤링 하기
#
# 1. 유튜브 랭킹 화면을 반복문으로 여러 페이지를 크롤링하자.
#     - 2초 간격 time.sleep(2)  이용
# 2. 데이터 프레임에 결과를 변환하고 엑셀 파일로 저장한다.

# %%
# 반복문으로 유튜브 랭킹 화면의 여러 페이지를 크롤링하기
results = []
for page in range(1,11):
# Out:
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=1
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=2
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=3
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=4
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=5
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=6
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=7
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=8
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=9
# https://youtube-rank.com/board/bbs/board.php?bo_table=youtube&page=10

# %% [markdown]
# 2. 데이터 프레임에 결과를 변환하고 엑셀 파일로 저장한다.

# %%
# 데이터 칼럼명을 설정하고 엑셀 파일로 저장하기
# title', 'category', 'subscriber', 'view', 'video'
# Out:
#                          title    category subscriber       view   video
# 0                    BLACKPINK  [음악/댄스/가수]      8310만  280억1103만    451개
# 1                    BANGTANTV  [음악/댄스/가수]      7210만  185억8512만  1,858개
# 2                  HYBE LABELS  [음악/댄스/가수]      6890만  252억7790만  1,036개
# 3                       SMTOWN  [음악/댄스/가수]      3110만  259억0878만  4,001개
# 4  Boram Tube Vlog [보람튜브 브이로그]    [키즈/어린이]      2650만  110억5288만    223개

# %%
# 'youtube_rank.xlsx' 로 저장

# %%
# %ls *.xlsx
# Out:
# youtube_rank.xlsx*

# %%
del driver

# %%
del df

# %% [markdown]
# # 2. 유튜브 랭킹 데이터 시각화하기

# %%
# 라이브러리 추가하기
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 그래프에서 한글을 표기하기 위한 글꼴 변경(윈도우, macOS에 대해 각각 처리)
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 전역 폰트 설정 사용
# font_path = 'C:/Windows/Fonts/NanumGothic.ttf'
# font_path = '/Users/qkboo/Library/Fonts/NanumGothic.otf'
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"

fontname = fm.FontProperties(fname=font_path, size=18).get_name()  # 폰트 패밀리 이름!
# plt.rc('font', family=fontname)
plt.rcParams["font.family"] = fontname
plt.rcParams["font.size"] = 12

# matplotlib 설정
plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (10,3)
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000

plt.title('한글 타이틀...')
# Out:
# Text(0.5, 1.0, '한글 타이틀...')

# %%
# 엑셀 파일 불러오기
df =  
df.head()
# Out:
#                          title    category subscriber       view   video
# 0                    BLACKPINK  [음악/댄스/가수]      8310만  280억1103만    451개
# 1                    BANGTANTV  [음악/댄스/가수]      7210만  185억8512만  1,858개
# 2                  HYBE LABELS  [음악/댄스/가수]      6890만  252억7790만  1,036개
# 3                       SMTOWN  [음악/댄스/가수]      3110만  259억0878만  4,001개
# 4  Boram Tube Vlog [보람튜브 브이로그]    [키즈/어린이]      2650만  110억5288만    223개

# %%
# 데이터 살펴보기
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       1000 non-null   object
#  1   category    1000 non-null   object
#  2   subscriber  1000 non-null   object
#  3   view        1000 non-null   object
#  4   video       1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
# 가입자 subscriber 데이터 10개 살펴보기
# Out:
# 0    8310만
# 1    7210만
# 2    6890만
# 3    3110만
# 4    2650만
# 5    2600만
# 6    2570만
# 7    2430만
# 8    1990만
# 9    1840만
# Name: subscriber, dtype: object

# %%
# 가입자 subscribe 의 '만' --> 0000 단위로 교체
# Out:
# 0    83100000
# 1    72100000
# 2    68900000
# 3    31100000
# 4    26500000
# 5    26000000
# 6    25700000
# 7    24300000
# 8    19900000
# 9    18400000
# Name: subscriber, dtype: object

# %%
# 가입자 subscribe 의 '만' --> 0000 단위로 교체
# 가입자 숫자 10000단위 데이터 변환




df.head()
# Out:
#                          title    category subscriber       view   video
# 0                    BLACKPINK  [음악/댄스/가수]   83100000  280억1103만    451개
# 1                    BANGTANTV  [음악/댄스/가수]   72100000  185억8512만  1,858개
# 2                  HYBE LABELS  [음악/댄스/가수]   68900000  252억7790만  1,036개
# 3                       SMTOWN  [음악/댄스/가수]   31100000  259억0878만  4,001개
# 4  Boram Tube Vlog [보람튜브 브이로그]    [키즈/어린이]   26500000  110억5288만    223개

# %%
# 데이터 상세 정보
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       1000 non-null   object
#  1   category    1000 non-null   object
#  2   subscriber  1000 non-null   object
#  3   view        1000 non-null   object
#  4   video       1000 non-null   object
# dtypes: object(5)
# memory usage: 39.2+ KB

# %%
# 가입자 subscribe 를 int 로 변경


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       1000 non-null   object
#  1   category    1000 non-null   object
#  2   subscriber  1000 non-null   int64
#  3   view        1000 non-null   object
#  4   video       1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
# 카테고리별 구독자 수, 채널 수의 합산/개수로 피봇 테이블 생성하기
pivot_df = df.pivot_table(index = 'category', values = 'subscriber', aggfunc = ['sum','count'])
pivot_df.head()
# Out:
#                    sum      count
#             subscriber subscriber
# category
# [BJ/인물/연예인]  102220000         63
# [IT/기술/컴퓨터]    9070000          7
# [TV/방송]      260780000        129
# [게임]          66320000         53
# [교육/강의]       27380000         21

# %%
# 데이터프레임의 칼럼명 변경하기




pivot_df.head()
# Out:
#              subscriber_sum  category_count
# category
# [BJ/인물/연예인]       102220000              63
# [IT/기술/컴퓨터]         9070000               7
# [TV/방송]           260780000             129
# [게임]               66320000              53
# [교육/강의]            27380000              21

# %%
# 데이터 프레임의 인덱스 초기화 하기




pivot_df.head()
# Out:
#       category  subscriber_sum  category_count
# 0  [BJ/인물/연예인]       102220000              63
# 1  [IT/기술/컴퓨터]         9070000               7
# 2      [TV/방송]       260780000             129
# 3         [게임]        66320000              53
# 4      [교육/강의]        27380000              21

# %%
# pivot_df 데이터 프레임을 내림차순 정렬하기




pivot_df.head()
# Out:
#        category  subscriber_sum  category_count
# 12   [음악/댄스/가수]       791130000             160
# 16     [키즈/어린이]       389120000             133
# 2       [TV/방송]       260780000             129
# 7         [미분류]       217220000             160
# 11  [음식/요리/레시피]       208330000              72

# %%
# pivot_df 카테고리별 구독자수 시각화 하기

# %%
# pivot_df 카테고리별 채널 수 시각화하기
