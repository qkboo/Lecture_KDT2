# %% [markdown]
# # Web Crawling

# %% [markdown]
# ### 이해할 기술
#  - HTTP 구성 및 동작
#  - HTML / CSS / (Javascript) 구조

# %% [markdown]
# ## HTTP
#
#  - HTML/CSS/javascipt/text/csv/json/xml 등등의 TEXT 데이터를 교환 목적.
#  - binary data 교환
#  - 자체적으로 압축!

# %% [markdown]
# ## RESTFull API (REST API)
#  - HTTP 의 7가지 메서드 이용 데이터 교환/업데이트

# %% [markdown]
# ![image.png](attachment:f045685f-00fa-4f04-ab0d-c99c21ee5726.png)

# %% [markdown]
# ## HTTP 요청/응답
#  - 요청 URL
#  - 응답 코드

# %% [markdown]
# ### 도메인

# %% [markdown]
# ![image.png](attachment:9cf20a8b-b653-4bfe-a109-323e90dc5e4a.png)

# %% [markdown]
# ![image.png](attachment:226a3c1a-7ae7-4853-8430-bafe95aa30c2.png)

# %% [markdown]
# ### URL 구조

# %% [markdown]
# ![image.png](attachment:0e11cd79-b41f-41b7-a950-3c8bc331e53c.png)

# %% [markdown]
# ### Query Strings
#
#  - parameter

# %% [markdown]
# ![image.png](attachment:a2f1a393-73d4-4eb7-b153-81fbc9f3cf58.png)

# %% [markdown]
# ### data 형식 --> 2차원
#
#  - xml : 'a' -> 20개 부가적
#  - html : HTML 규정  (xml) : 'a' -> 8개 부가적.
#  - txt : ascii text ( unicodd text) : 'a'
#  - csv : ',' 텍스트 (이름,나이,주소(40) ) : 'a'
#  - json : 'a' -> 3개
#  - binary

# %% [markdown]
# 학생정보 -> 세부적 형식/크기 / ....

# %% [markdown]
# ## HTML
#
#  - https://www.w3schools.com/html/

# %% [markdown]
# ![image.png](attachment:7792dd27-5288-4532-9e88-f745262c6d0d.png)

# %% [markdown]
# ### CSS Selector
#   - https://poiemaweb.com/css3-selector
#
# ![image.png](attachment:1f36be76-e875-49bd-ab50-38fb53c9c9f1.png)

# %% [markdown]
# ### Python CSS Selector
#
#  - https://wikidocs.net/82625https://wikidocs.net/82625
